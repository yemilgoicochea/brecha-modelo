# %%
# -*- coding: utf-8 -*-
"""
- Leer los proyectos desde el CSV "proyecto_limpio_4".
- Ejecutar el modelo fila por fila (saltando filas con ID = 0).
- Guardar la respuesta JSON en la columna "JSON_RPTA".
- Exportar el resultado a "resultados1.csv".
"""

# !pip install -q google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata
import os
import json
import time
import pandas as pd  # <- NUEVO: para manejar el CSV

# -------------------------------------------------------------------
# 0. Configurar API de Gemini
# -------------------------------------------------------------------
API_KEY = userdata.get('BRECHAS_API_KEY')

if API_KEY is None:
    raise ValueError(
        "No se encontró la API Key. Por favor, guárdala en los secretos de Colab "
        "bajo el nombre 'BRECHAS_API_KEY'."
    )

genai.configure(api_key=API_KEY)
print("API de Gemini configurada exitosamente.")

# Elegir modelo
GEMINI_MODEL_NAME = "gemini-2.5-flash"
model = genai.GenerativeModel(GEMINI_MODEL_NAME)
# Out:
# API de Gemini configurada exitosamente.

# %% [markdown]
# ##1. Definiciones de categorías

# %%
# -------------------------------------------------------------------
# 1. Definiciones de categorías
# -------------------------------------------------------------------
CATEGORIAS = {
    "CATEGORIA_1": {
        "id": 1,
        "nombre": "servicio de alcantarillado u otras formas de disposicion sanitaria de excretas",
        "definicion": """
Texto describe al menos uno (1) de los siguientes servicios:

1. SERVICIO DE ALCANTARILLADO: incluye al menos uno (1) de los siguientes procesos con aguas residuales:
   recolección, impulsión, conducción hasta el punto de entrega y tratamiento.

2. SERVICIO DE DISPOSICIÓN SANITARIA DE EXCRETAS: incluye instalaciones intradomiciliarias
   (como Unidades Básicas Sanitarias - UBS, letrinas, etc.) y/o procesos para la disposición final del agua residual
   o las excretas.
"""
    },

    "CATEGORIA_2": {
        "id": 2,
        "nombre": "servicio de agua potable mediante red publica o pileta publica",
        "definicion": """
comprende al menos uno (1) de los siguientes servicios:
1. sistema de producción: captación, almacenamiento y conducción de agua cruda, tratamiento y conducción de agua potable.
2. sistema de distribución: almacenamiento, distribución, entrega y medición al usuario.

comprende instalaciones como:
1. red pública: conexión domiciliaria.
2. pileta públicas: punto de abastecimiento de agua potable instalado en el espacio público.
"""
    },

    "CATEGORIA_3": {
        "id": 3,
        "nombre": "aguas residuales no tratadas",
        "definicion": """
El servicio de tratamiento de aguas residuales para disposición final incluye instalar, mejorar o ampliar instalaciones que permitan procesos con aguas residuales.

PROCESOS: el servicio comprende uno o ninguno:
* recolección
* impulsión o conducción hasta la planta de tratamiento
* tratamiento o reúso del efluente
* disposición final

EJEMPLOS DE TECNOLOGÍAS DE TRATAMIENTO INCLUIDAS (no limitativo):
* PTAR – Plantas de Tratamiento de Aguas Residuales.
* Biorreactores de membrana (MBR).
* Ósmosis inversa y ultrafiltración.
"""
    },

    "CATEGORIA_4": {
        "id": 4,
        "nombre": "m2 de espacios publicos verdes por implementar",
        "definicion": """
Incluye espacios públicos como los siguientes (no limitativo):
* Parque
* Plaza
* Jardín
* Alameda
* Bosque Urbano
* Zona de Esparcimiento
"""
    },

    "CATEGORIA_5": {
        "id": 5,
        "nombre": "servicios de movilidad a traves de pistas y veredas",
        "definicion": """
El SERVICIO DE MOVILIDAD permite la transitabilidad a través de infraestructura vial.

Ejemplos de infraestructura vial urbana (no limitativo):
* pista
* calle
* pasaje
* avenida
* vías urbanas
* vías principales
* vereda
* puente
* óvalo
"""
    },

    "CATEGORIA_6": {
        "id": 6,
        "nombre": "servicio de educacion inicial",
        "definicion": """
El SERVICIO DE EDUCACIÓN INICIAL atiende a niños menores de 6 años con enfoque intercultural e inclusivo.
Promueve el desarrollo infantil en dimensiones cognitiva, física, motora, social y emocional.

Incluye la implementación de recursos educativos:
* infraestructura
* equipos
* personal
* organización
* capacidad de gestión
* otros

Servicios complementarios (uno o ninguno):
* atención en salud
* nutrición
* protección
* acceso al registro legal de identidad
* servicios de cuidado
* otros servicios que aseguren condiciones básicas para el desarrollo infantil
"""
    },

    "CATEGORIA_7": {
        "id": 7,
        "nombre": "servicio de educacion primaria",
        "definicion": """
El SERVICIO DE EDUCACIÓN PRIMARIA atiende a niños y niñas desde los 6 años.

Incluye:
* infraestructura
* equipos
* personal
* organización
* capacidad de gestión

Objetivos del servicio:
* desarrollo del pensamiento lógico y matemático
* comunicación, expresión artística y psicomotricidad
* aprendizajes en ciencia, humanidades y tecnología
* estrategias diversificadas según ritmos y niveles de aprendizaje
* atención a la pluralidad lingüística y cultural
"""
    },

    "CATEGORIA_8": {
        "id": 8,
        "nombre": "servicio de educacion secundaria",
        "definicion": """
El SERVICIO DE EDUCACIÓN SECUNDARIA atiende a adolescentes e incluye:

* infraestructura
* equipos
* personal
* organización
* capacidad de gestión

Objetivos del servicio:
* formación humanística, científica y tecnológica
* capacitación para el trabajo
* promoción de competencias emprendedoras orientadas al desarrollo de proyectos productivos con uso de tecnologías

NO se considera parte del servicio:
* Colegios de Alto Rendimiento (COAR)

Nota: II.EE = Instituciones Educativas.
"""
    }
}

# %% [markdown]
# ## 2. Construcción del prompt

# %%
# -------------------------------------------------------------------
# 2. Construcción del prompt
# -------------------------------------------------------------------
def construir_prompt(texto_proyecto: str) -> str:
    """
    Construye un prompt en español para que Gemini actúe como
    clasificador multi-etiqueta basado en las definiciones de categorías.

    Recibe directamente el título/descripción del proyecto como string.
    """
    texto_proyecto = str(texto_proyecto).strip()

    partes_categorias = []
    for clave, info in CATEGORIAS.items():
        partes_categorias.append(
            f"- ID: {info['id']}\n"
            f"  NOMBRE: {info['nombre']}\n"
            f"  DEFINICION: {info['definicion'].strip()}\n"
        )
    texto_categorias = "\n".join(partes_categorias)

    prompt = f"""
Eres un modelo de lenguaje experto en clasificación de títulos de proyectos públicos
según brechas de infraestructura y servicios definidas por el SNPMGI del Perú.

Tu única tarea es leer el título del proyecto y asignarle UNA O VARIAS categorías
de servicios publicos de la lista definida abajo.

CATEGORÍAS DISPONIBLES:
{texto_categorias}

REGLAS ESTRICTAS:
- Analiza el significado del título del proyecto, no solo palabras sueltas.
- Asigna múltiples categorías solo si el título realmente cubre más de una brecha.
- No inventes información adicional que no esté presente o inferida razonablemente del título del proyecto.

FORMATO DE RESPUESTA (OBLIGATORIO):
Responde ÚNICAMENTE con JSON válido, sin texto adicional, sin explicaciones, sin backticks.
Ejemplo de formato:

{{
  "labels": [
    {{
      "label": "NOMBRE_DE_CATEGORIA_1",
      "id":1,
      "confianza": 0.95,
      "justificacion": "Texto de la justificacion"
    }},
    {{
      "label": "NOMBRE_DE_CATEGORIA_2",
      "id":3,
      "confianza": 0.98,
      "justificacion": "Texto de la justificacion"
    }}
  ]
}}

donde:
- "labels" es una lista de objetos.
- "label" es el nombre de la categoría seleccionada.
- "id": es el identificador numérico único asignado a cada categoría. Debes devolver exactamente el id asociado a la categoría, según la lista de categorías proporcionada en el prompt.
- "confianza": representa el nivel de certeza del modelo sobre la asignación de una categoría. Debe ser un valor numérico entre 0 y 1.
- "justificacion": explica por qué el proyecto fue clasificado en esa categoria usando unicamente la DEFINICIÓN de la categoria. máximo 200 palabras.

Si el título del proyecto es ambiguo o no coincide con ninguna definición, debes devolver:

{{
  "labels": [
    {{
      "label": "NO_CLASIFICADO",
      "id": 0,
      "confianza": 0.0,
      "justificacion": "El texto no es suficiente o no coincide con ninguna categoría."
    }}
  ]
}}

TEXTO A CLASIFICAR:
\"\"\"{texto_proyecto}\"\"\"
"""
    return prompt

# %% [markdown]
# 3. Utilidad para limpiar y extraer JSON de la respuesta del modelo

# %%
# -------------------------------------------------------------------
# 3. Utilidad para limpiar y extraer JSON de la respuesta del modelo
# -------------------------------------------------------------------
def extraer_json_de_texto(texto: str) -> str:
    """
    Intenta limpiar la salida del modelo y extraer solo la parte JSON.

    - Elimina backticks de bloques de código (```json ... ```).
    - Toma el contenido entre la primera '{' y la última '}'.
    - Valida que sea JSON.
    """
    if texto is None:
        raise json.JSONDecodeError("Respuesta vacía del modelo", "", 0)

    s = texto.strip()

    # 1) Quitar bloques de código markdown si los hubiera
    if s.startswith("```"):
        # eliminar primera línea (``` o ```json)
        first_newline = s.find("\n")
        if first_newline != -1:
            s = s[first_newline + 1:]
        # eliminar ``` final si está
        if s.endswith("```"):
            s = s[:-3]
        s = s.strip()

    # 2) Quedarnos con lo que está entre la primera '{' y la última '}'
    start = s.find("{")
    end = s.rfind("}")
    if start != -1 and end != -1 and end > start:
        s = s[start:end + 1]

    # 3) Intentar parsear como JSON
    obj = json.loads(s)  # si falla, lanza JSONDecodeError
    # 4) Devolverlo normalizado (string JSON)
    return json.dumps(obj, ensure_ascii=False)

# %% [markdown]
#  4. Función para llamar a Gemini y devolver JSON limpio

# %%
# -------------------------------------------------------------------
# 4. Función para llamar a Gemini y devolver JSON limpio
# -------------------------------------------------------------------
def ejecutar_prompt(prompt: str, max_reintentos: int = 3, espera_segundos: int = 2) -> str:
    """
    Envía el prompt al modelo de Gemini y devuelve la respuesta como JSON limpio (string).
    Si la respuesta no es JSON válido, devuelve un JSON de error.
    """
    for intento in range(1, max_reintentos + 1):
        try:
            respuesta = model.generate_content(prompt)
            texto = (respuesta.text or "").strip()

            try:
                json_limpio = extraer_json_de_texto(texto)
                return json_limpio
            except json.JSONDecodeError as e:
                # Si el modelo no respetó el formato, devolvemos error pero guardamos la respuesta cruda
                return json.dumps({
                    "labels": [],
                    "error": "La respuesta del modelo no es JSON válido",
                    "detalle_error": str(e),
                    "raw_response": texto
                }, ensure_ascii=False)

        except Exception as e:
            print(f"[Intento {intento}] Error al llamar a Gemini: {e}")
            time.sleep(espera_segundos)

    # Si falla todos los intentos, devolvemos un JSON de error
    return json.dumps({
        "labels": [],
        "error": "No se pudo obtener respuesta del modelo luego de varios intentos."
    }, ensure_ascii=False)

# %% [markdown]
# 5. Punto de entrada principal: leer CSV y procesar fila por fila

# %%
# -------------------------------------------------------------------
# 5. Punto de entrada principal: leer CSV y procesar fila por fila
# -------------------------------------------------------------------
if __name__ == "__main__":
    print("=== Clasificador de proyectos públicos (Gemini) ===")
    print("Leyendo archivo 'proyecto_limpio_4.csv'...")

    # Ajusta 'sep' si CSV no usa ; como delimitador
    df = pd.read_csv(
        "proyecto_limpio_4.csv",
        sep=';',
        dtype=str,         # mantener todo como texto
        encoding='utf-8'
    )

    # Concatenar NATURALEZA_PROYECTO + NOMBRE DEL PROYECTO_limpio
    df['TITULO_PROYECTO_MODEL'] = (
        df['NATURALEZA_PROYECTO'].fillna('') + ' ' +
        df['NOMBRE DEL PROYECTO_limpio'].fillna('')
    ).str.strip()

    resultados_json = []

    print("Ejecutando el modelo fila por fila (saltando ID = 0)...")

    for idx, fila in df.iterrows():
        id_val = str(fila.get('ID', '0')).strip()

        # Si ID es 0, no se llama al modelo; se deja respuesta vacía
        if id_val == '0':
            resultados_json.append("")
            continue

        titulo_proyecto = fila['TITULO_PROYECTO_MODEL']
        if not isinstance(titulo_proyecto, str) or not titulo_proyecto.strip():
            # Si el título concatenado está vacío, también dejamos vacío
            resultados_json.append("")
            continue

        prompt = construir_prompt(titulo_proyecto)
        respuesta_json_str = ejecutar_prompt(prompt)
        resultados_json.append(respuesta_json_str)

        # Mensaje simple de seguimiento
        print(f"Fila {idx}: procesada (ID={id_val}).")

    # Agregar columna con la respuesta JSON
    df['JSON_RPTA'] = resultados_json

    # Exportar resultados
    salida = "resultados1.csv"
    df.to_csv(salida, sep=';', index=False, encoding='utf-8-sig')
    print(f"\nProceso completado. Archivo exportado como '{salida}'.")
# Out:
# === Clasificador de proyectos públicos (Gemini) ===
# Leyendo archivo 'proyecto_limpio_4.csv'...
# Ejecutando el modelo fila por fila (saltando ID = 0)...
# Fila 0: procesada (ID=5).
# Fila 1: procesada (ID=5).
# Fila 2: procesada (ID=5).
# Fila 3: procesada (ID=5).
# Fila 5: procesada (ID=5).
# Fila 6: procesada (ID=4).
# Fila 7: procesada (ID=2).
# Fila 8: procesada (ID=2).
# Fila 10: procesada (ID=2).
# Fila 11: procesada (ID=2).
# Fila 12: procesada (ID=5).
# Fila 13: procesada (ID=5).
# Fila 15: procesada (ID=5).
# Fila 16: procesada (ID=4).
# Fila 18: procesada (ID=5).
# Fila 19: procesada (ID=5).
# Fila 20: procesada (ID=4).
# Fila 21: procesada (ID=5).
# Fila 22: procesada (ID=4).
# Fila 23: procesada (ID=4).
# Fila 24: procesada (ID=2).
# Fila 25: procesada (ID=2).
# Fila 28: procesada (ID=5).
# Fila 30: procesada (ID=5).
# Fila 31: procesada (ID=5).
# Fila 32: procesada (ID=5).
# Fila 34: procesada (ID=2).
# Fila 36: procesada (ID=2).
# Fila 37: procesada (ID=2).
# Fila 39: procesada (ID=1).
# Fila 40: procesada (ID=2).
# Fila 41: procesada (ID=5).
# Fila 42: procesada (ID=2).
# Fila 43: procesada (ID=5).
# Fila 44: procesada (ID=5).
# Fila 47: procesada (ID=4).
# Fila 48: procesada (ID=4).
# Fila 49: procesada (ID=5).
# Fila 50: procesada (ID=5).
# Fila 51: procesada (ID=4).
# Fila 52: procesada (ID=1).
# Fila 53: procesada (ID=2).
# Fila 54: procesada (ID=5).
# Fila 55: procesada (ID=5).
# Fila 57: procesada (ID=4).
# Fila 58: procesada (ID=2).
# Fila 59: procesada (ID=2).
# Fila 60: procesada (ID=2).
# Fila 61: procesada (ID=2).
# Fila 62: procesada (ID=2).
# Fila 63: procesada (ID=2).
# Fila 64: procesada (ID=1).
# Fila 65: procesada (ID=2).
# Fila 66: procesada (ID=1).
# Fila 67: procesada (ID=2).
# Fila 68: procesada (ID=5).
# Fila 69: procesada (ID=2).
# Fila 70: procesada (ID=1).
# Fila 71: procesada (ID=5).
# Fila 74: procesada (ID=1).
# Fila 75: procesada (ID=4).
# Fila 76: procesada (ID=5).
# Fila 77: procesada (ID=2).
# Fila 79: procesada (ID=2).
# Fila 80: procesada (ID=1).
# Fila 81: procesada (ID=1).
# Fila 82: procesada (ID=5).
# Fila 83: procesada (ID=5).
# Fila 85: procesada (ID=2).
# Fila 86: procesada (ID=5).
# Fila 87: procesada (ID=5).
# Fila 91: procesada (ID=4).
# Fila 92: procesada (ID=2).
# Fila 93: procesada (ID=1).
# Fila 94: procesada (ID=1).
# Fila 95: procesada (ID=2).
# Fila 96: procesada (ID=1).
# Fila 97: procesada (ID=2).
# Fila 98: procesada (ID=2).
# Fila 99: procesada (ID=1).
# Fila 100: procesada (ID=1).
# Fila 101: procesada (ID=2).
# Fila 102: procesada (ID=2).
# Fila 103: procesada (ID=1).
# Fila 104: procesada (ID=2).
# Fila 105: procesada (ID=2).
# Fila 106: procesada (ID=1).
# Fila 108: procesada (ID=1).
# Fila 109: procesada (ID=2).
# Fila 110: procesada (ID=1).
# Fila 111: procesada (ID=4).
# Fila 112: procesada (ID=4).
# Fila 113: procesada (ID=5).
# Fila 114: procesada (ID=1).
# Fila 115: procesada (ID=2).
# Fila 117: procesada (ID=5).
# Fila 118: procesada (ID=5).
# Fila 119: procesada (ID=5).
# Fila 120: procesada (ID=4).
# Fila 121: procesada (ID=3).
# Fila 122: procesada (ID=5).
# Fila 123: procesada (ID=1).
# Fila 124: procesada (ID=2).
# Fila 125: procesada (ID=2).
# Fila 126: procesada (ID=1).
# Fila 127: procesada (ID=2).
# Fila 128: procesada (ID=2).
# Fila 129: procesada (ID=2).
# Fila 130: procesada (ID=1).
# Fila 131: procesada (ID=4).
# Fila 132: procesada (ID=1).
# Fila 133: procesada (ID=2).
# Fila 134: procesada (ID=1).
# Fila 135: procesada (ID=1).
# Fila 136: procesada (ID=2).
# Fila 138: procesada (ID=1).
# Fila 139: procesada (ID=2).
# Fila 140: procesada (ID=5).
# Fila 141: procesada (ID=1).
# Fila 142: procesada (ID=2).
# Fila 143: procesada (ID=5).
# Fila 144: procesada (ID=5).
# Fila 146: procesada (ID=2).
# Fila 148: procesada (ID=3).
# Fila 149: procesada (ID=1).
# Fila 150: procesada (ID=2).
# Fila 152: procesada (ID=1).
# Fila 154: procesada (ID=5).
# Fila 155: procesada (ID=5).
# Fila 156: procesada (ID=4).
# Fila 158: procesada (ID=5).
# Fila 159: procesada (ID=3).
# Fila 160: procesada (ID=2).
# Fila 161: procesada (ID=1).
# Fila 162: procesada (ID=2).
# Fila 163: procesada (ID=2).
# Fila 164: procesada (ID=1).
# Fila 165: procesada (ID=2).
# Fila 167: procesada (ID=1).
# Fila 168: procesada (ID=4).
# Fila 169: procesada (ID=5).
# Fila 170: procesada (ID=1).
# Fila 171: procesada (ID=2).
# Fila 172: procesada (ID=5).
# Fila 173: procesada (ID=4).
# Fila 174: procesada (ID=2).
# Fila 175: procesada (ID=4).
# Fila 177: procesada (ID=5).
# Fila 179: procesada (ID=1).
# Fila 180: procesada (ID=2).
# Fila 181: procesada (ID=1).
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1441.11ms
# Fila 182: procesada (ID=2).
# Fila 183: procesada (ID=5).
# Fila 184: procesada (ID=2).
# Fila 185: procesada (ID=1).
# Fila 187: procesada (ID=5).
# Fila 188: procesada (ID=1).
# Fila 189: procesada (ID=2).
# Fila 190: procesada (ID=5).
# Fila 191: procesada (ID=5).
# Fila 192: procesada (ID=5).
# Fila 193: procesada (ID=5).
# Fila 194: procesada (ID=5).
# Fila 198: procesada (ID=2).
# Fila 199: procesada (ID=1).
# Fila 200: procesada (ID=5).
# Fila 202: procesada (ID=4).
# Fila 203: procesada (ID=5).
# Fila 207: procesada (ID=4).
# Fila 209: procesada (ID=5).
# Fila 210: procesada (ID=6).
# Fila 211: procesada (ID=1).
# Fila 212: procesada (ID=5).
# Fila 213: procesada (ID=2).
# Fila 214: procesada (ID=2).
# Fila 215: procesada (ID=1).
# Fila 216: procesada (ID=1).
# Fila 217: procesada (ID=2).
# Fila 218: procesada (ID=1).
# Fila 219: procesada (ID=2).
# Fila 220: procesada (ID=1).
# Fila 221: procesada (ID=2).
# Fila 222: procesada (ID=5).
# Fila 223: procesada (ID=2).
# Fila 224: procesada (ID=5).
# Fila 226: procesada (ID=5).
# Fila 227: procesada (ID=5).
# Fila 228: procesada (ID=2).
# Fila 231: procesada (ID=2).
# Fila 232: procesada (ID=2).
# Fila 233: procesada (ID=1).
# Fila 234: procesada (ID=2).
# Fila 235: procesada (ID=2).
# Fila 236: procesada (ID=5).
# Fila 237: procesada (ID=5).
# Fila 238: procesada (ID=4).
# Fila 239: procesada (ID=1).
# Fila 240: procesada (ID=2).
# Fila 241: procesada (ID=2).
# Fila 242: procesada (ID=2).
# Fila 245: procesada (ID=2).
# Fila 246: procesada (ID=1).
# Fila 247: procesada (ID=5).
# Fila 248: procesada (ID=4).
# Fila 249: procesada (ID=5).
# Fila 250: procesada (ID=5).
# Fila 251: procesada (ID=1).
# Fila 252: procesada (ID=2).
# Fila 253: procesada (ID=5).
# Fila 254: procesada (ID=5).
# Fila 255: procesada (ID=5).
# Fila 256: procesada (ID=5).
# Fila 257: procesada (ID=5).
# Fila 259: procesada (ID=2).
# Fila 267: procesada (ID=4).
# Fila 269: procesada (ID=5).
# Fila 270: procesada (ID=5).
# Fila 271: procesada (ID=2).
# Fila 272: procesada (ID=1).
# Fila 273: procesada (ID=2).
# Fila 274: procesada (ID=1).
# Fila 275: procesada (ID=1).
# Fila 276: procesada (ID=2).
# Fila 277: procesada (ID=2).
# Fila 278: procesada (ID=1).
# Fila 279: procesada (ID=2).
# Fila 280: procesada (ID=1).
# Fila 281: procesada (ID=2).
# Fila 286: procesada (ID=2).
# Fila 287: procesada (ID=5).
# Fila 288: procesada (ID=5).
# Fila 289: procesada (ID=1).
# Fila 290: procesada (ID=5).
# Fila 291: procesada (ID=5).
# Fila 292: procesada (ID=1).
# Fila 293: procesada (ID=2).
# Fila 296: procesada (ID=2).
# Fila 297: procesada (ID=2).
# Fila 298: procesada (ID=1).
# Fila 299: procesada (ID=1).
# Fila 300: procesada (ID=6).
# Fila 301: procesada (ID=6).
# Fila 305: procesada (ID=4).
# Fila 307: procesada (ID=5).
# Fila 308: procesada (ID=5).
# Fila 309: procesada (ID=5).
# Fila 310: procesada (ID=4).
# Fila 311: procesada (ID=4).
# Fila 313: procesada (ID=4).
# Fila 314: procesada (ID=5).
# Fila 315: procesada (ID=1).
# Fila 316: procesada (ID=2).
# Fila 317: procesada (ID=5).
# Fila 318: procesada (ID=5).
# Fila 319: procesada (ID=1).
# Fila 320: procesada (ID=2).
# Fila 322: procesada (ID=5).
# Fila 323: procesada (ID=7).
# Fila 324: procesada (ID=5).
# Fila 325: procesada (ID=2).
# Fila 326: procesada (ID=1).
# Fila 327: procesada (ID=1).
# Fila 328: procesada (ID=1).
# Fila 329: procesada (ID=1).
# Fila 330: procesada (ID=2).
# Fila 332: procesada (ID=4).
# Fila 333: procesada (ID=2).
# Fila 334: procesada (ID=4).
# Fila 335: procesada (ID=2).
# Fila 336: procesada (ID=6).
# Fila 337: procesada (ID=7).
# Fila 338: procesada (ID=2).
# Fila 339: procesada (ID=1).
# Fila 340: procesada (ID=2).
# Fila 341: procesada (ID=7).
# Fila 342: procesada (ID=1).
# Fila 343: procesada (ID=4).
# Fila 344: procesada (ID=2).
# Fila 345: procesada (ID=4).
# Fila 347: procesada (ID=1).
# Fila 348: procesada (ID=2).
# Fila 349: procesada (ID=1).
# Fila 350: procesada (ID=5).
# Fila 352: procesada (ID=5).
# Fila 353: procesada (ID=7).
# Fila 354: procesada (ID=2).
# Fila 355: procesada (ID=5).
# Fila 357: procesada (ID=5).
# Fila 359: procesada (ID=2).
# Fila 360: procesada (ID=7).
# Fila 364: procesada (ID=7).
# Fila 365: procesada (ID=4).
# Fila 366: procesada (ID=2).
# Fila 367: procesada (ID=4).
# Fila 368: procesada (ID=4).
# Fila 369: procesada (ID=4).
# Fila 370: procesada (ID=8).
# Fila 371: procesada (ID=4).
# Fila 372: procesada (ID=2).
# Fila 373: procesada (ID=1).
# Fila 374: procesada (ID=5).
# Fila 375: procesada (ID=5).
# Fila 379: procesada (ID=1).
# Fila 380: procesada (ID=2).
# Fila 381: procesada (ID=7).
# Fila 382: procesada (ID=7).
# Fila 383: procesada (ID=5).
# Fila 384: procesada (ID=5).
# Fila 385: procesada (ID=4).
# Fila 386: procesada (ID=2).
# Fila 387: procesada (ID=1).
# Fila 388: procesada (ID=2).
# Fila 389: procesada (ID=1).
# Fila 390: procesada (ID=4).
# Fila 391: procesada (ID=2).
# Fila 393: procesada (ID=2).
# Fila 394: procesada (ID=1).
# Fila 395: procesada (ID=1).
# Fila 396: procesada (ID=7).
# Fila 397: procesada (ID=7).
# Fila 398: procesada (ID=1).
# Fila 399: procesada (ID=4).
# Fila 400: procesada (ID=5).
# Fila 401: procesada (ID=1).
# Fila 402: procesada (ID=5).
# Fila 403: procesada (ID=2).
# Fila 404: procesada (ID=1).
# Fila 408: procesada (ID=5).
# Fila 409: procesada (ID=5).
# Fila 410: procesada (ID=6).
# Fila 411: procesada (ID=1).
# Fila 412: procesada (ID=2).
# Fila 413: procesada (ID=2).
# Fila 417: procesada (ID=1).
# Fila 418: procesada (ID=2).
# Fila 419: procesada (ID=6).
# Fila 420: procesada (ID=5).
# Fila 421: procesada (ID=5).
# Fila 422: procesada (ID=2).
# Fila 423: procesada (ID=6).
# Fila 424: procesada (ID=5).
# Fila 425: procesada (ID=1).
# Fila 426: procesada (ID=5).
# Fila 428: procesada (ID=4).
# Fila 429: procesada (ID=5).
# Fila 430: procesada (ID=5).
# Fila 431: procesada (ID=1).
# Fila 432: procesada (ID=5).
# Fila 434: procesada (ID=5).
# Fila 435: procesada (ID=2).
# Fila 436: procesada (ID=2).
# Fila 437: procesada (ID=4).
# Fila 438: procesada (ID=6).
# Fila 439: procesada (ID=6).
# Fila 441: procesada (ID=7).
# Fila 443: procesada (ID=1).
# Fila 445: procesada (ID=2).
# Fila 446: procesada (ID=1).
# Fila 447: procesada (ID=7).
# Fila 450: procesada (ID=2).
# Fila 451: procesada (ID=1).
# Fila 452: procesada (ID=4).
# Fila 453: procesada (ID=7).
# Fila 455: procesada (ID=3).
# Fila 456: procesada (ID=1).
# Fila 457: procesada (ID=7).
# Fila 459: procesada (ID=5).
# Fila 460: procesada (ID=5).
# Fila 462: procesada (ID=8).
# Fila 466: procesada (ID=2).
# Fila 467: procesada (ID=1).
# Fila 468: procesada (ID=1).
# Fila 469: procesada (ID=2).
# Fila 470: procesada (ID=1).
# Fila 473: procesada (ID=6).
# Fila 474: procesada (ID=4).
# Fila 476: procesada (ID=1).
# Fila 477: procesada (ID=2).
# Fila 478: procesada (ID=8).
# Fila 480: procesada (ID=8).
# Fila 482: procesada (ID=5).
# Fila 483: procesada (ID=4).
# Fila 485: procesada (ID=5).
# Fila 487: procesada (ID=7).
# Fila 488: procesada (ID=7).
# Fila 489: procesada (ID=8).
# Fila 490: procesada (ID=4).
# Fila 492: procesada (ID=5).
# Fila 493: procesada (ID=7).
# Fila 495: procesada (ID=4).
# Fila 497: procesada (ID=7).
# Fila 498: procesada (ID=5).
# Fila 499: procesada (ID=1).
# Fila 501: procesada (ID=8).
# Fila 502: procesada (ID=2).
# Fila 503: procesada (ID=6).
# Fila 506: procesada (ID=8).
# Fila 509: procesada (ID=5).
# Fila 510: procesada (ID=1).
# Fila 511: procesada (ID=7).
# Fila 512: procesada (ID=7).
# Fila 513: procesada (ID=1).
# Fila 514: procesada (ID=2).
# Fila 517: procesada (ID=1).
# Fila 518: procesada (ID=2).
# Fila 519: procesada (ID=6).
# Fila 520: procesada (ID=2).
# Fila 521: procesada (ID=5).
# Fila 522: procesada (ID=2).
# Fila 523: procesada (ID=1).
# Fila 524: procesada (ID=4).
# Fila 527: procesada (ID=1).
# Fila 528: procesada (ID=7).
# Fila 529: procesada (ID=5).
# Fila 530: procesada (ID=4).
# Fila 531: procesada (ID=7).
# Fila 534: procesada (ID=2).
# Fila 536: procesada (ID=8).
# Fila 537: procesada (ID=5).
# Fila 538: procesada (ID=8).
# Fila 539: procesada (ID=7).
# Fila 540: procesada (ID=5).
# Fila 541: procesada (ID=1).
# Fila 543: procesada (ID=7).
# Fila 546: procesada (ID=5).
# Fila 547: procesada (ID=4).
# Fila 549: procesada (ID=2).
# Fila 550: procesada (ID=1).
# Fila 551: procesada (ID=5).
# Fila 556: procesada (ID=5).
# Fila 558: procesada (ID=4).
# Fila 562: procesada (ID=5).
# Fila 563: procesada (ID=2).
# Fila 564: procesada (ID=5).
# Fila 565: procesada (ID=5).
# Fila 566: procesada (ID=6).
# Fila 568: procesada (ID=2).
# Fila 570: procesada (ID=1).
# Fila 571: procesada (ID=8).
# Fila 572: procesada (ID=8).
# Fila 573: procesada (ID=7).
# Fila 574: procesada (ID=2).
# Fila 575: procesada (ID=1).
# Fila 576: procesada (ID=4).
# Fila 577: procesada (ID=5).
# Fila 578: procesada (ID=7).
# Fila 579: procesada (ID=7).
# Fila 581: procesada (ID=2).
# Fila 582: procesada (ID=1).
# Fila 583: procesada (ID=4).
# Fila 584: procesada (ID=8).
# Fila 585: procesada (ID=2).
# Fila 586: procesada (ID=7).
# Fila 588: procesada (ID=8).
# Fila 590: procesada (ID=5).
# Fila 591: procesada (ID=6).
# Fila 593: procesada (ID=2).
# Fila 594: procesada (ID=5).
# Fila 595: procesada (ID=4).
# Fila 596: procesada (ID=2).
# Fila 597: procesada (ID=5).
# Fila 598: procesada (ID=7).
# Fila 599: procesada (ID=5).
# Fila 603: procesada (ID=6).
# Fila 604: procesada (ID=6).
# Fila 605: procesada (ID=6).
# Fila 606: procesada (ID=5).
# Fila 607: procesada (ID=5).
# Fila 609: procesada (ID=6).
# Fila 611: procesada (ID=5).
# Fila 614: procesada (ID=6).
# Fila 615: procesada (ID=8).
# Fila 616: procesada (ID=4).
# Fila 618: procesada (ID=2).
# Fila 620: procesada (ID=4).
# Fila 621: procesada (ID=1).
# Fila 622: procesada (ID=1).
# Fila 623: procesada (ID=5).
# Fila 628: procesada (ID=7).
# Fila 629: procesada (ID=5).
# Fila 631: procesada (ID=4).
# Fila 634: procesada (ID=4).
# Fila 636: procesada (ID=5).
# Fila 637: procesada (ID=4).
# Fila 639: procesada (ID=7).
# Fila 641: procesada (ID=2).
# Fila 642: procesada (ID=7).
# Fila 643: procesada (ID=1).
# Fila 644: procesada (ID=2).
# Fila 646: procesada (ID=1).
# Fila 647: procesada (ID=7).
# Fila 649: procesada (ID=2).
# Fila 650: procesada (ID=1).
# Fila 651: procesada (ID=7).
# Fila 655: procesada (ID=7).
# Fila 656: procesada (ID=5).
# Fila 658: procesada (ID=6).
# Fila 659: procesada (ID=5).
# Fila 666: procesada (ID=5).
# Fila 667: procesada (ID=5).
# Fila 668: procesada (ID=6).
# Fila 670: procesada (ID=4).
# Fila 674: procesada (ID=8).
# Fila 676: procesada (ID=6).
# Fila 677: procesada (ID=8).
# Fila 680: procesada (ID=5).
# Fila 681: procesada (ID=4).
# Fila 683: procesada (ID=8).
# Fila 684: procesada (ID=6).
# Fila 686: procesada (ID=1).
# Fila 687: procesada (ID=2).
# Fila 689: procesada (ID=1).
# Fila 692: procesada (ID=1).
# Fila 693: procesada (ID=1).
# Fila 695: procesada (ID=1).
# Fila 696: procesada (ID=1).
# Fila 698: procesada (ID=5).
# Fila 701: procesada (ID=1).
# Fila 704: procesada (ID=2).
# Fila 705: procesada (ID=1).
# Fila 706: procesada (ID=5).
# Fila 708: procesada (ID=2).
# Fila 709: procesada (ID=1).
# Fila 711: procesada (ID=4).
# Fila 712: procesada (ID=1).
# Fila 713: procesada (ID=1).
# Fila 715: procesada (ID=5).
# Fila 719: procesada (ID=5).
# Fila 720: procesada (ID=5).
# Fila 722: procesada (ID=8).
# Fila 723: procesada (ID=5).
# Fila 724: procesada (ID=2).
# Fila 725: procesada (ID=1).
# Fila 728: procesada (ID=8).
# Fila 732: procesada (ID=1).
# Fila 734: procesada (ID=1).
# Fila 738: procesada (ID=4).
# Fila 739: procesada (ID=2).
# Fila 740: procesada (ID=4).
# Fila 741: procesada (ID=4).
# Fila 742: procesada (ID=7).
# Fila 744: procesada (ID=7).
# Fila 745: procesada (ID=2).
# Fila 746: procesada (ID=2).
# Fila 747: procesada (ID=6).
# Fila 748: procesada (ID=7).
# Fila 749: procesada (ID=8).
# Fila 750: procesada (ID=5).
# Fila 751: procesada (ID=4).
# Fila 752: procesada (ID=5).
# Fila 753: procesada (ID=4).
# Fila 754: procesada (ID=5).
# Fila 755: procesada (ID=1).
# Fila 756: procesada (ID=5).
# Fila 758: procesada (ID=8).
# Fila 759: procesada (ID=2).
# Fila 760: procesada (ID=1).
# Fila 761: procesada (ID=6).
# Fila 763: procesada (ID=2).
# Fila 764: procesada (ID=2).
# Fila 766: procesada (ID=4).
# Fila 767: procesada (ID=5).
# Fila 768: procesada (ID=1).
# Fila 769: procesada (ID=2).
# Fila 772: procesada (ID=4).
# Fila 774: procesada (ID=2).
# Fila 775: procesada (ID=5).
# Fila 776: procesada (ID=4).
# Fila 780: procesada (ID=7).
# Fila 781: procesada (ID=7).
# Fila 785: procesada (ID=7).
# Fila 786: procesada (ID=2).
# Fila 787: procesada (ID=4).
# Fila 788: procesada (ID=2).
# Fila 789: procesada (ID=7).
# Fila 790: procesada (ID=7).
# Fila 791: procesada (ID=8).
# Fila 793: procesada (ID=5).
# Fila 794: procesada (ID=2).
# Fila 797: procesada (ID=5).
# Fila 798: procesada (ID=4).
# Fila 799: procesada (ID=8).
# Fila 800: procesada (ID=7).
# Fila 801: procesada (ID=2).
# Fila 803: procesada (ID=2).
# Fila 805: procesada (ID=5).
# Fila 807: procesada (ID=2).
# Fila 809: procesada (ID=8).
# Fila 810: procesada (ID=5).
# Fila 811: procesada (ID=1).
# Fila 812: procesada (ID=2).
# Fila 813: procesada (ID=6).
# Fila 814: procesada (ID=6).
#
# Proceso completado. Archivo exportado como 'resultados1.csv'.
